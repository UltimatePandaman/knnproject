# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Specifikuj cestu k souboru CSV
FILENAME = 'baseline_transcribe_results.csv'

# Načtení CSV souboru do DataFrame
data = pd.read_csv(FILENAME)
data
# Out:
#     source_speaker target_speaker                                  ref_file  \
# 0             p225           p226    ../baseline_data/source/p225-val/1.wav
# 1             p225           p226   ../baseline_data/source/p225-val/10.wav
# 2             p225           p226   ../baseline_data/source/p225-val/11.wav
# 3             p225           p226   ../baseline_data/source/p225-val/12.wav
# 4             p225           p226   ../baseline_data/source/p225-val/13.wav
# ..             ...            ...                                       ...
# 115           p230           p229  ../baseline_data/source/p230-val/101.wav
# 116           p230           p229  ../baseline_data/source/p230-val/107.wav
# 117           p230           p229  ../baseline_data/source/p230-val/102.wav
# 118           p230           p229   ../baseline_data/source/p230-val/10.wav
# 119           p230           p229  ../baseline_data/source/p230-val/103.wav
#
#                                            ref_content  \
# 0     it is a common problem six spoons of fresh sn...
# 1     in existence for alan the action reflects a s...
# 2     he will go a long way irvine said his company...
# 3     overall it was a promising day for the scots ...
# 4     it was a close call everything happened so qu...
# ..                                                 ...
# 115   i'm afraid to say anything no evidence that i...
# 116   for her brother bob i can hardly believe it w...
# 117   we have to build a new team in the minimum of...
# 118   a patent certainly the taliban regime is fini...
# 119   the announcement was made after inquiries fro...
#
#                                     gen_file  \
# 0      ../baseline_data/converted/p225/1.wav
# 1     ../baseline_data/converted/p225/10.wav
# 2     ../baseline_data/converted/p225/11.wav
# 3     ../baseline_data/converted/p225/12.wav
# 4     ../baseline_data/converted/p225/13.wav
# ..                                       ...
# 115  ../baseline_data/converted/p230/101.wav
# 116  ../baseline_data/converted/p230/107.wav
# 117  ../baseline_data/converted/p230/102.wav
# 118   ../baseline_data/converted/p230/10.wav
# 119  ../baseline_data/converted/p230/103.wav
#
#                                            gen_content      score
# 0     it is a common problem 6 spoons of fresh slow...   88.23529
# 1     in existence alan the action reflects a slump...   81.81818
# 2     he will go a long way irvine said his company...  100.00000
# 3     overall it was a promising day for the scots ...   85.00000
# 4     it was a close call everything happened so qu...  100.00000
# ..                                                 ...        ...
# 115   i'm afraid to say anything no evidence that i...  100.00000
# 116   for her brother bob i can hardly believe it w...  100.00000
# 117   we have to build a new team in the minimum of...  100.00000
# 118   a patent certainly the taliban regime is fini...   93.75000
# 119   the announcement was made after inquiries fro...   68.42105
#
# [120 rows x 7 columns]

# %%
result_summary = data.groupby(['source_speaker', 'target_speaker']).agg({'score': ['mean', 'std', 'max', lambda x: f"{(x == 100).sum()}/10"]})
result_summary.columns = ['mean_score', 'std_deviation', 'max_score', 'match_count']
result_summary = result_summary.sort_values(by='mean_score', ascending=False)

result_summary
# Out:
#                                mean_score  std_deviation  max_score  \
# source_speaker target_speaker
# p256           p254             92.823480       7.781361  100.00000
# p226           p225             90.841308       8.933704  100.00000
# p225           p226             90.710763       6.214223  100.00000
# p228           p227             90.706065       7.637968  100.00000
# p227           p228             89.861965       7.588810  100.00000
# p230           p229             89.270990      13.537505  100.00000
# p243           p232             88.852141       8.736484  100.00000
# p223           p243             88.686820       6.812225  100.00000
# p229           p230             87.842987       5.293579   96.42857
# p254           p256             85.830886       7.661303   95.45455
# p231           p233             85.324085      11.995053   94.44444
# p233           p231             85.317527       7.287275   94.73684
#
#                               match_count
# source_speaker target_speaker
# p256           p254                  4/10
# p226           p225                  4/10
# p225           p226                  2/10
# p228           p227                  1/10
# p227           p228                  3/10
# p230           p229                  4/10
# p243           p232                  2/10
# p223           p243                  1/10
# p229           p230                  0/10
# p254           p256                  0/10
# p231           p233                  0/10
# p233           p231                  0/10

# %%
# Vytvoření boxplotu pro skóre podle kombinace source_speaker a target_speaker
plt.figure(figsize=(11, 5))
sns.boxplot(x='source_speaker', y='score', hue='target_speaker', data=data, width=0.7, dodge=False)
plt.title('Boxplot of transcript scores by source_speaker and target_speaker')
plt.xlabel('Source Speaker')
plt.ylabel('Transcript score')
plt.xticks(rotation=45)
plt.legend(title='Target Speaker', bbox_to_anchor=(1.005, 1), loc='upper left')
plt.show()
